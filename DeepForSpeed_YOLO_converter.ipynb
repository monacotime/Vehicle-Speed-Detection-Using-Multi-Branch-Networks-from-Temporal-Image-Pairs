# %%
from google.colab import drive
drive.mount('/content/gdrive')
# !ln -s /content/gdrive/My\ Drive/ /mydrive
# !ls /mydrive
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# 4/3wGO0Ntzc1A3DJwg_7yIgipqIHXty8FV43hovK1Cgaz0-rm6Oik8I3s
# Mounted at /content/gdrive
#  Classroom	    datasets	     'My documents'	      YOLO
# 'Colab Notebooks'  'Files to share'  'Sem 5 IoT data files'   yolov3

# %%
# !git clone https://github.com/hunglc007/tensorflow-yolov4-tflite.git
# Out:
# Cloning into 'tensorflow-yolov4-tflite'...
# remote: Enumerating objects: 780, done.
# remote: Total 780 (delta 0), reused 0 (delta 0), pack-reused 780
# Receiving objects: 100% (780/780), 197.64 MiB | 26.73 MiB/s, done.
# Resolving deltas: 100% (371/371), done.

# %%
# !cp /mydrive/YOLO/trained_weights/DeepForSpeed/yolov3-tiny_training_final.weights /content/tensorflow-yolov4-tflite/data/yolov3-tiny.weights

# %%
#!!! first change the data/classes/coco.names -> your classes

# %%
# %cd tensorflow-yolov4-tflite
# !ls
# Out:
# /content/tensorflow-yolov4-tflite
# android		    core	    LICENSE		  result-int8.png
# benchmarks.py	    data	    mAP			  result.png
# CODE_OF_CONDUCT.md  detect.py	    README.md		  save_model.py
# convert_tflite.py   detectvideo.py  requirements-gpu.txt  scripts
# convert_trt.py	    evaluate.py     requirements.txt	  train.py

# %%
# !python save_model.py --weights ./data/yolov3-tiny.weights --output ./checkpoints/yolov3-tiny-416 --input_size 416 --model yolov3 --tiny --framework tflite
# Out:
# 2020-09-08 21:49:42.825168: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2020-09-08 21:49:44.467088: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2020-09-08 21:49:44.470172: E tensorflow/stream_executor/cuda/cuda_driver.cc:314] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2020-09-08 21:49:44.470224: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (9ccc83baaf38): /proc/driver/nvidia/version does not exist
# 2020-09-08 21:49:44.476437: I tensorflow/core/platform/profile_utils/cpu_utils.cc:104] CPU Frequency: 2200000000 Hz
# 2020-09-08 21:49:44.476655: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x2e8ca00 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# ...

# %%
# !python convert_tflite.py --weights ./checkpoints/yolov3-tiny-416 --output ./checkpoints/yolov3-tiny-416-int8.tflite --quantize_mode full_int8
# Out:
# 2020-09-08 21:57:29.306366: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2020-09-08 21:57:31.110907: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2020-09-08 21:57:31.114034: E tensorflow/stream_executor/cuda/cuda_driver.cc:314] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2020-09-08 21:57:31.114080: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (9ccc83baaf38): /proc/driver/nvidia/version does not exist
# 2020-09-08 21:57:31.120755: I tensorflow/core/platform/profile_utils/cpu_utils.cc:104] CPU Frequency: 2200000000 Hz
# 2020-09-08 21:57:31.121014: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x2a58a00 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# ...

# %%
# !cp ./checkpoints/yolov3-tiny-416-int8.tflite /mydrive/YOLO/trained_weights/DeepForSpeed/yolov3-tiny-416-int8.tflite
